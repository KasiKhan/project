# %% [markdown]
# KHAN KASI

# %% [markdown]
# Process Developer

# %% [markdown]
# I am interested in data science because of competence building in the area of process automation

# %%
My code is suppose to print my name
# Out:
#   File "/tmp/wsuser/ipykernel_164/552146531.py", line 1
#     My code is suppose to print my name
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# Print (Khan Kasi)
